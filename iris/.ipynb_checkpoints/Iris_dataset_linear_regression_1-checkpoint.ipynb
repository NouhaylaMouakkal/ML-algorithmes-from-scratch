# %% [markdown]
# # Regression Linéaire Simple du dataset Iris - Gradient Descent

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## 1. Dataset
# Chargement du dataset Iris pour effectuer les prédictions de la largeur des pétales en fonction de longueur des pétales

# %%
dataset=pd.read_csv("iris.csv")

# %%
dataset.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
import seaborn as sns
numeric_columns = dataset.drop(columns=['class'])
numeric_columns.corr()
plt.figure()
sns.heatmap(numeric_columns.corr(),annot=True)
plt.show()

# %%
plt.plot(dataset["petal_width"],dataset["petal_length"],'o')
plt.xlabel('petal_length')
plt.ylabel('sepal_length')
plt.show()

# %%
df=dataset[['petal_length','sepal_length']]
df
# Out:
#      petal_length  sepal_length
# 0             1.4           5.1
# 1             1.4           4.9
# 2             1.3           4.7
# 3             1.5           4.6
# 4             1.4           5.0
# ..            ...           ...
# 145           5.2           6.7
# 146           5.0           6.3
# 147           5.2           6.5
# 148           5.4           6.2
# 149           5.1           5.9
#
# [150 rows x 2 columns]

# %%
x=dataset.petal_length
y=dataset.sepal_length

# %%
x.shape
# Out:
# (150,)

# %%
y
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepal_length, Length: 150, dtype: float64

# %%
y.shape
# Out:
# (150,)

# %% [markdown]
# Important: Après avoir vérifié les dimensions de x et y, On remarque que y n'a pas les dimensions (150, 1) et x n'a pas les dimensions (150,2). On corrige le problème avec np.reshape et values.

# %%
X=dataset.petal_length.values
Y=dataset.sepal_length.values
X
# Out:
# array([1.4, 1.4, 1.3, 1.5, 1.4, 1.7, 1.4, 1.5, 1.4, 1.5, 1.5, 1.6, 1.4,
#        1.1, 1.2, 1.5, 1.3, 1.4, 1.7, 1.5, 1.7, 1.5, 1. , 1.7, 1.9, 1.6,
#        1.6, 1.5, 1.4, 1.6, 1.6, 1.5, 1.5, 1.4, 1.5, 1.2, 1.3, 1.5, 1.3,
#        1.5, 1.3, 1.3, 1.3, 1.6, 1.9, 1.4, 1.6, 1.4, 1.5, 1.4, 4.7, 4.5,
#        4.9, 4. , 4.6, 4.5, 4.7, 3.3, 4.6, 3.9, 3.5, 4.2, 4. , 4.7, 3.6,
#        4.4, 4.5, 4.1, 4.5, 3.9, 4.8, 4. , 4.9, 4.7, 4.3, 4.4, 4.8, 5. ,
#        4.5, 3.5, 3.8, 3.7, 3.9, 5.1, 4.5, 4.5, 4.7, 4.4, 4.1, 4. , 4.4,
#        4.6, 4. , 3.3, 4.2, 4.2, 4.2, 4.3, 3. , 4.1, 6. , 5.1, 5.9, 5.6,
#        5.8, 6.6, 4.5, 6.3, 5.8, 6.1, 5.1, 5.3, 5.5, 5. , 5.1, 5.3, 5.5,
#        6.7, 6.9, 5. , 5.7, 4.9, 6.7, 4.9, 5.7, 6. , 4.8, 4.9, 5.6, 5.8,
#        6.1, 6.4, 5.6, 5.1, 5.6, 6.1, 5.6, 5.5, 4.8, 5.4, 5.6, 5.1, 5.1,
#        5.9, 5.7, 5.2, 5. , 5.2, 5.4, 5.1])

# %%
X.shape
# Out:
# (150,)

# %%
x=dataset.petal_length.values.reshape(150,1)
y=dataset.sepal_length.values.reshape(150,1)

# %%
print(x.shape)
print(y.shape)
# Out:
# (150, 1)
# (150, 1)

# %% [markdown]
# Création de la matrice X qui contient la colonne de Biais. Pour ca, on colle l'un contre l'autre le vecteur x et un vecteur 1 (avec np.ones) de dimension égale a celle de x

# %%
#X=np.hstack((np.ones((150,1)),x))
X=np.hstack((x,(np.ones(x.shape))))
X
# Out:
# array([[1.4, 1. ],
#        [1.4, 1. ],
#        [1.3, 1. ],
#        [1.5, 1. ],
#        [1.4, 1. ],
#        [1.7, 1. ],
#        [1.4, 1. ],
#        [1.5, 1. ],
#        [1.4, 1. ],
#        [1.5, 1. ],
#        [1.5, 1. ],
#        [1.6, 1. ],
#        [1.4, 1. ],
#        [1.1, 1. ],
#        [1.2, 1. ],
#        [1.5, 1. ],
#        [1.3, 1. ],
#        [1.4, 1. ],
#        [1.7, 1. ],
#        [1.5, 1. ],
#        [1.7, 1. ],
#        [1.5, 1. ],
#        [1. , 1. ],
#        [1.7, 1. ],
#        [1.9, 1. ],
#        [1.6, 1. ],
#        [1.6, 1. ],
#        [1.5, 1. ],
#        [1.4, 1. ],
#        [1.6, 1. ],
#        [1.6, 1. ],
#        [1.5, 1. ],
#        [1.5, 1. ],
#        [1.4, 1. ],
#        [1.5, 1. ],
#        [1.2, 1. ],
#        [1.3, 1. ],
#        [1.5, 1. ],
#        [1.3, 1. ],
#        [1.5, 1. ],
#        [1.3, 1. ],
#        [1.3, 1. ],
#        [1.3, 1. ],
#        [1.6, 1. ],
#        [1.9, 1. ],
#        [1.4, 1. ],
#        [1.6, 1. ],
#        [1.4, 1. ],
#        [1.5, 1. ],
#        [1.4, 1. ],
#        [4.7, 1. ],
#        [4.5, 1. ],
#        [4.9, 1. ],
#        [4. , 1. ],
#        [4.6, 1. ],
#        [4.5, 1. ],
#        [4.7, 1. ],
#        [3.3, 1. ],
#        [4.6, 1. ],
#        [3.9, 1. ],
#        [3.5, 1. ],
#        [4.2, 1. ],
#        [4. , 1. ],
#        [4.7, 1. ],
#        [3.6, 1. ],
#        [4.4, 1. ],
#        [4.5, 1. ],
#        [4.1, 1. ],
#        [4.5, 1. ],
#        [3.9, 1. ],
#        [4.8, 1. ],
#        [4. , 1. ],
#        [4.9, 1. ],
#        [4.7, 1. ],
#        [4.3, 1. ],
#        [4.4, 1. ],
#        [4.8, 1. ],
#        [5. , 1. ],
#        [4.5, 1. ],
#        [3.5, 1. ],
#        [3.8, 1. ],
#        [3.7, 1. ],
#        [3.9, 1. ],
#        [5.1, 1. ],
#        [4.5, 1. ],
#        [4.5, 1. ],
#        [4.7, 1. ],
#        [4.4, 1. ],
#        [4.1, 1. ],
#        [4. , 1. ],
#        [4.4, 1. ],
#        [4.6, 1. ],
#        [4. , 1. ],
#        [3.3, 1. ],
#        [4.2, 1. ],
#        [4.2, 1. ],
#        [4.2, 1. ],
#        [4.3, 1. ],
#        [3. , 1. ],
#        [4.1, 1. ],
#        [6. , 1. ],
#        [5.1, 1. ],
#        [5.9, 1. ],
#        [5.6, 1. ],
#        [5.8, 1. ],
#        [6.6, 1. ],
#        [4.5, 1. ],
#        [6.3, 1. ],
#        [5.8, 1. ],
#        [6.1, 1. ],
#        [5.1, 1. ],
#        [5.3, 1. ],
#        [5.5, 1. ],
#        [5. , 1. ],
#        [5.1, 1. ],
#        [5.3, 1. ],
#        [5.5, 1. ],
#        [6.7, 1. ],
#        [6.9, 1. ],
#        [5. , 1. ],
#        [5.7, 1. ],
#        [4.9, 1. ],
#        [6.7, 1. ],
#        [4.9, 1. ],
#        [5.7, 1. ],
#        [6. , 1. ],
#        [4.8, 1. ],
#        [4.9, 1. ],
#        [5.6, 1. ],
#        [5.8, 1. ],
#        [6.1, 1. ],
#        [6.4, 1. ],
#        [5.6, 1. ],
#        [5.1, 1. ],
#        [5.6, 1. ],
#        [6.1, 1. ],
#        [5.6, 1. ],
#        [5.5, 1. ],
#        [4.8, 1. ],
#        [5.4, 1. ],
#        [5.6, 1. ],
#        [5.1, 1. ],
#        [5.1, 1. ],
#        [5.9, 1. ],
#        [5.7, 1. ],
#        [5.2, 1. ],
#        [5. , 1. ],
#        [5.2, 1. ],
#        [5.4, 1. ],
#        [5.1, 1. ]])

# %%
X.shape
# Out:
# (150, 2)

# %% [markdown]
# Finalement, création d'un vecteur parametre θ, initialisé avec des coefficients aléatoires. Ce vecteur est de dimension (2, 1). Si on désire toujours reproduire le meme vecteur
# θ, on utilise comme avant np.random.seed(0)

# %%
np.random.seed(0) # pour produire toujours le meme vecteur theta aléatoire
theta=np.random.randn(2,1)
print('Theta:',theta)
# Out:
# Theta: [[1.76405235]
#  [0.40015721]]

# %% [markdown]
# ## 2. Modèle Linéaire
# On implémente un modèle selon l'équation matricielle F=X.θ et puis on teste le modèle initiale défini par la valeur initiale de θ qu'on a initialisé d'une manière aléatoire.

# %%
def model(X, theta):
    return X.dot(theta)

# %%
plt.plot(x,y,'o',label='dataset')
plt.plot(x, model(X, theta), c='r',label='modèle initial')
plt.xlabel('petal_length')
plt.ylabel('sepal_length')
plt.legend()
plt.show()

# %% [markdown]
# ## 3. Fonction coût : Erreur Quadratique Moyenne
# On mesure les erreurs du modele sur le Dataset X, y en implémenterl'erreur quadratique moyenne, Mean Squared Error (MSE) en anglais.
# ![Capture%20d'%C3%A9cran%202023-04-04%20113116.png](attachment:Capture%20d'%C3%A9cran%202023-04-04%20113116.png)
#
# Ensuite, on teste notre fonction, pour voir s'il n'y a pas de bug

# %%
def cost_function(X, y, theta):
    m = len(y)
    return 1/(2*m) * np.sum((model(X, theta) - y)**2)

# %%
cost_function(X, y, theta)
# Out:
# 3.6251772822189268

# %% [markdown]
# ![Capture%20d'%C3%A9cran%202023-04-04%20114408.png](attachment:Capture%20d'%C3%A9cran%202023-04-04%20114408.png)

# %%
def grad(X, y, theta):
    m = len(y)
    return 1/m * X.T.dot(model(X, theta) - y)

# %%
def gradient_descent(X, y, theta, learning_rate, n_iterations):
    
    cost_history = np.zeros(n_iterations) # création d'un tableau de stockage pour enregistrer l'évolution du Cout du modele
    
    for i in range(0, n_iterations):
        theta = theta - learning_rate * grad(X, y, theta) # mise a jour du parametre theta (formule du gradient descent)
        cost_history[i] = cost_function(X, y, theta) # on enregistre la valeur du Cout au tour i dans cost_history[i]
        
    return theta, cost_history

# %% [markdown]
# ## 5. Phase d'entrainement
# On définit un nombre d'itérations, ainsi qu'un pas d'apprentissage α. Une fois le modele entrainé, on observe les resultats par rapport a notre Dataset

# %%
n_iterations = 300 #0.02172855 l'erreur minimale pour 1000 itéreations
learning_rate = 0.9


theta_final, cost_history = gradient_descent(X, y, theta, learning_rate, n_iterations)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_5584\247847267.py:3: RuntimeWarning: overflow encountered in square
#   return 1/(2*m) * np.sum((model(X, theta) - y)**2)
# C:\Users\hp\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:86: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# C:\Users\hp\AppData\Local\Temp\ipykernel_5584\627494581.py:6: RuntimeWarning: invalid value encountered in subtract
#   theta = theta - learning_rate * grad(X, y, theta) # mise a jour du parametre theta (formule du gradient descent)

# %%
cost_history # l'historique de la fonction coût qu'on va afficher par la suite. on remarque que sa valeur déminue et c'est ça l'objectif
# Out:
# array([4.88968748e+002, 1.13365070e+005, 2.63428260e+007, 6.12136941e+009,
#        1.42244284e+012, 3.30537745e+014, 7.68081485e+016, 1.78481633e+019,
#        4.14743671e+021, 9.63753578e+023, 2.23950604e+026, 5.20401422e+028,
#        1.20927399e+031, 2.81002993e+033, 6.52975944e+035, 1.51734178e+038,
#        3.52589726e+040, 8.19324401e+042, 1.90389119e+045, 4.42413489e+047,
#        1.02805085e+050, 2.38891574e+052, 5.55120247e+054, 1.28995127e+057,
#        2.99750240e+059, 6.96539540e+061, 1.61857195e+064, 3.76112915e+066,
#        8.73986012e+068, 2.03091018e+071, 4.71929313e+073, 1.09663774e+076,
#        2.54829337e+078, 5.92155354e+080, 1.37601097e+083, 3.19748217e+085,
#        7.43009501e+087, 1.72655574e+090, 4.01205464e+092, 9.32294398e+094,
#        2.16640331e+097, 5.03414298e+099, 1.16980044e+102, 2.71830396e+104,
#        6.31661276e+106, 1.46781219e+109, 3.41080369e+111, 7.92579728e+113,
#        1.84174371e+116, 4.27972074e+118, 9.94492855e+120, 2.31093592e+123,
#        5.36999818e+125, 1.24784423e+128, 2.89965688e+130, 6.73802853e+132,
#        1.56573796e+135, 3.63835706e+137, 8.45457056e+139, 1.96461651e+142,
#        4.56524431e+144, 1.06084091e+147, 2.46511109e+149, 5.72826012e+151,
#        1.33109474e+154, 3.09310884e+156, 7.18755926e+158, 1.67019690e+161,
#        3.88109175e+163, 9.01862119e+165, 2.09568682e+168, 4.86981673e+170,
#        1.13161541e+173, 2.62957213e+175, 6.11042368e+177, 1.41989935e+180,
#        3.29946705e+182, 7.66708064e+184, 1.78162487e+187, 4.14002061e+189,
#        9.62030273e+191, 2.23550154e+194, 5.19470883e+196, 1.20711166e+199,
#        2.80500527e+201, 6.51808346e+203, 1.51462860e+206, 3.51959254e+208,
#        8.17859352e+210, 1.90048681e+213, 4.41622402e+215, 1.02621257e+218,
#        2.38464408e+220, 5.54127626e+222, 1.28764468e+225, 2.99214251e+227,
#        6.95294045e+229, 1.61567775e+232, 3.75440380e+234, 8.72423221e+236,
#        2.02727868e+239, 4.71085447e+241, 1.09467682e+244, 2.54373672e+246,
#        5.91096510e+248, 1.37355050e+251, 3.19176470e+253, 7.41680912e+255,
#        1.72346845e+258, 4.00488061e+260, 9.30627345e+262, 2.16252952e+265,
#        5.02514133e+267, 1.16770870e+270, 2.71344331e+272, 6.30531791e+274,
#        1.46518756e+277, 3.40470477e+279, 7.91162502e+281, 1.83845046e+284,
#        4.27206809e+286, 9.92714584e+288, 2.30680369e+291, 5.36039599e+293,
#        1.24561293e+296, 2.89447195e+298, 6.72598014e+300, 1.56293824e+303,
#        3.63185124e+305,             inf,             inf,             inf,
#                    inf,             inf,             inf,             inf,
#                    inf,             inf,             inf,             inf,
#                    inf,             inf,             inf,             inf,
#                    inf,             inf,             inf,             inf,
#                    inf,             inf,             inf,             inf,
#                    inf,             inf,             inf,             inf,
#                    inf,             inf,             inf,             inf,
#                    inf,             inf,             inf,             inf,
#                    inf,             inf,             inf,             inf,
#                    inf,             inf,             inf,             inf,
#                    inf,             inf,             inf,             inf,
#                    inf,             inf,             inf,             inf,
#                    inf,             inf,             inf,             inf,
#                    inf,             inf,             inf,             inf,
#                    inf,             inf,             inf,             inf,
#                    inf,             inf,             inf,             inf,
#                    inf,             inf,             inf,             inf,
#                    inf,             inf,             inf,             inf,
#                    inf,             inf,             inf,             inf,
#                    inf,             inf,             inf,             inf,
#                    inf,             inf,             inf,             inf,
#                    inf,             inf,             inf,             inf,
#                    inf,             inf,             inf,             inf,
#                    inf,             inf,             inf,             inf,
#                    inf,             inf,             inf,             inf,
#                    inf,             inf,             inf,             inf,
#                    inf,             inf,             inf,             inf,
#                    inf,             inf,             inf,             inf,
#                    inf,             inf,             inf,             inf,
#                    inf,             inf,             inf,             inf,
#                    inf,             inf,             inf,             inf,
#                    inf,             inf,             inf,             nan,
#                    nan,             nan,             nan,             nan,
#                    nan,             nan,             nan,             nan,
#                    nan,             nan,             nan,             nan,
#                    nan,             nan,             nan,             nan,
#                    nan,             nan,             nan,             nan,
#                    nan,             nan,             nan,             nan,
#                    nan,             nan,             nan,             nan,
#                    nan,             nan,             nan,             nan,
#                    nan,             nan,             nan,             nan,
#                    nan,             nan,             nan,             nan])

# %%
theta_final # voici les parametres du modele une fois que la machine a été entrainée
# Out:
# array([[nan],
#        [nan]])

# %%
theta_final[0]
# Out:
# array([nan])

# %%
# création d'un vecteur prédictions qui contient les prédictions de notre modele final
predictions = model(X, theta_final)

# Affichage des résultats de prédictions (en rouge) par rapport a notre Dataset (en bleu)
plt.plot(x,y,'o',label='dataset')
plt.plot(x,predictions , c='r',label='prédictions')
plt.xlabel('petal_length')
plt.ylabel('sepal_length')
plt.legend()
plt.show()

# %%
# Test: # prédire la largeur d'un pétale qui a une longueur de 2,5 cm
X_2_5= np.array([2.5,1])
pred_y_2_5=model(X_2_5, theta_final) 
print(pred_y_2_5)
# Out:
# [nan]

# %% [markdown]
# ## 6. Courbe d'apprentissage
#
#    Pour vérifier si notre algorithme de Descente de gradient a bien fonctionné, on observe l'évolution de la fonction cout a travers les itérations. On est sensé obtenir une courbe qui diminue a chaque itération jusqu'a stagner a un niveau minimal (proche de zéro). Si la courbe ne suit pas ce motif, alors le pas learning_rate est peut-etre trop élevé, il faut prendre un pas plus faible.

# %%
plt.plot(range(n_iterations), cost_history)
plt.show()

# %% [markdown]
# ## 7. Evaluation du modèle - Coefficient de détermination
#
#    Le coefficient de détermination est un indice de la qualité de la prédiction de la régression linéaire. Le coefficient de détermination se situe entre 0 et 1. Plus il est proche de 1, plus la régression linéaire est en adéquation avec les données collectées

# %% [markdown]
# ![Capture%20d'%C3%A9cran%202023-04-04%20123236.png](attachment:Capture%20d'%C3%A9cran%202023-04-04%20123236.png)

# %%
def coef_determination(y, pred):
    u = ((y - pred)**2).sum()
    v = ((y - y.mean())**2).sum()
    return 1 - u/v

# %%
coef_determination(y, predictions)
# Out:
# nan

# %%
dataset.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000
