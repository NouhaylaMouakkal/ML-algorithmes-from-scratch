# %% [markdown]
# # Regression Linéaire Simple du dataset Iris - Gradient Descent

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## 1. Dataset
# Chargement du dataset Iris pour effectuer les prédictions de la largeur des pétales en fonction de longueur des pétales

# %%
dataset=pd.read_csv("iris.csv")

# %%
dataset.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
import seaborn as sns
numeric_columns = dataset.drop(columns=['class'])
numeric_columns.corr()
plt.figure()
sns.heatmap(numeric_columns.corr(),annot=True)
plt.show()

# %%
plt.plot(dataset["petal_width"],dataset["petal_length"],'o')
plt.xlabel('petal_length')
plt.ylabel('sepal_length')
plt.show()

# %%
df=dataset[['petal_length','sepal_length']]
df
# Out:
#      petal_length  sepal_length
# 0             1.4           5.1
# 1             1.4           4.9
# 2             1.3           4.7
# 3             1.5           4.6
# 4             1.4           5.0
# ..            ...           ...
# 145           5.2           6.7
# 146           5.0           6.3
# 147           5.2           6.5
# 148           5.4           6.2
# 149           5.1           5.9
#
# [150 rows x 2 columns]

# %%
x=dataset.petal_length
y=dataset.sepal_length

# %%
x.shape
# Out:
# (150,)

# %%
y
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepal_length, Length: 150, dtype: float64

# %%
y.shape
# Out:
# (150,)

# %% [markdown]
# Important: Après avoir vérifié les dimensions de x et y, On remarque que y n'a pas les dimensions (150, 1) et x n'a pas les dimensions (150,2). On corrige le problème avec np.reshape et values.

# %%
X=dataset.petal_length.values
Y=dataset.sepal_length.values
X
# Out:
# array([1.4, 1.4, 1.3, 1.5, 1.4, 1.7, 1.4, 1.5, 1.4, 1.5, 1.5, 1.6, 1.4,
#        1.1, 1.2, 1.5, 1.3, 1.4, 1.7, 1.5, 1.7, 1.5, 1. , 1.7, 1.9, 1.6,
#        1.6, 1.5, 1.4, 1.6, 1.6, 1.5, 1.5, 1.4, 1.5, 1.2, 1.3, 1.5, 1.3,
#        1.5, 1.3, 1.3, 1.3, 1.6, 1.9, 1.4, 1.6, 1.4, 1.5, 1.4, 4.7, 4.5,
#        4.9, 4. , 4.6, 4.5, 4.7, 3.3, 4.6, 3.9, 3.5, 4.2, 4. , 4.7, 3.6,
#        4.4, 4.5, 4.1, 4.5, 3.9, 4.8, 4. , 4.9, 4.7, 4.3, 4.4, 4.8, 5. ,
#        4.5, 3.5, 3.8, 3.7, 3.9, 5.1, 4.5, 4.5, 4.7, 4.4, 4.1, 4. , 4.4,
#        4.6, 4. , 3.3, 4.2, 4.2, 4.2, 4.3, 3. , 4.1, 6. , 5.1, 5.9, 5.6,
#        5.8, 6.6, 4.5, 6.3, 5.8, 6.1, 5.1, 5.3, 5.5, 5. , 5.1, 5.3, 5.5,
#        6.7, 6.9, 5. , 5.7, 4.9, 6.7, 4.9, 5.7, 6. , 4.8, 4.9, 5.6, 5.8,
#        6.1, 6.4, 5.6, 5.1, 5.6, 6.1, 5.6, 5.5, 4.8, 5.4, 5.6, 5.1, 5.1,
#        5.9, 5.7, 5.2, 5. , 5.2, 5.4, 5.1])

# %%
X.shape
# Out:
# (150,)

# %%
x=dataset.petal_length.values.reshape(150,1)
y=dataset.sepal_length.values.reshape(150,1)

# %%
print(x.shape)
print(y.shape)
# Out:
# (150, 1)
# (150, 1)

# %% [markdown]
# Création de la matrice X qui contient la colonne de Biais. Pour ca, on colle l'un contre l'autre le vecteur x et un vecteur 1 (avec np.ones) de dimension égale a celle de x

# %%
#X=np.hstack((np.ones((150,1)),x))
X=np.hstack((x,(np.ones(x.shape))))
X
# Out:
# array([[1.4, 1. ],
#        [1.4, 1. ],
#        [1.3, 1. ],
#        [1.5, 1. ],
#        [1.4, 1. ],
#        [1.7, 1. ],
#        [1.4, 1. ],
#        [1.5, 1. ],
#        [1.4, 1. ],
#        [1.5, 1. ],
#        [1.5, 1. ],
#        [1.6, 1. ],
#        [1.4, 1. ],
#        [1.1, 1. ],
#        [1.2, 1. ],
#        [1.5, 1. ],
#        [1.3, 1. ],
#        [1.4, 1. ],
#        [1.7, 1. ],
#        [1.5, 1. ],
#        [1.7, 1. ],
#        [1.5, 1. ],
#        [1. , 1. ],
#        [1.7, 1. ],
#        [1.9, 1. ],
#        [1.6, 1. ],
#        [1.6, 1. ],
#        [1.5, 1. ],
#        [1.4, 1. ],
#        [1.6, 1. ],
#        [1.6, 1. ],
#        [1.5, 1. ],
#        [1.5, 1. ],
#        [1.4, 1. ],
#        [1.5, 1. ],
#        [1.2, 1. ],
#        [1.3, 1. ],
#        [1.5, 1. ],
#        [1.3, 1. ],
#        [1.5, 1. ],
#        [1.3, 1. ],
#        [1.3, 1. ],
#        [1.3, 1. ],
#        [1.6, 1. ],
#        [1.9, 1. ],
#        [1.4, 1. ],
#        [1.6, 1. ],
#        [1.4, 1. ],
#        [1.5, 1. ],
#        [1.4, 1. ],
#        [4.7, 1. ],
#        [4.5, 1. ],
#        [4.9, 1. ],
#        [4. , 1. ],
#        [4.6, 1. ],
#        [4.5, 1. ],
#        [4.7, 1. ],
#        [3.3, 1. ],
#        [4.6, 1. ],
#        [3.9, 1. ],
#        [3.5, 1. ],
#        [4.2, 1. ],
#        [4. , 1. ],
#        [4.7, 1. ],
#        [3.6, 1. ],
#        [4.4, 1. ],
#        [4.5, 1. ],
#        [4.1, 1. ],
#        [4.5, 1. ],
#        [3.9, 1. ],
#        [4.8, 1. ],
#        [4. , 1. ],
#        [4.9, 1. ],
#        [4.7, 1. ],
#        [4.3, 1. ],
#        [4.4, 1. ],
#        [4.8, 1. ],
#        [5. , 1. ],
#        [4.5, 1. ],
#        [3.5, 1. ],
#        [3.8, 1. ],
#        [3.7, 1. ],
#        [3.9, 1. ],
#        [5.1, 1. ],
#        [4.5, 1. ],
#        [4.5, 1. ],
#        [4.7, 1. ],
#        [4.4, 1. ],
#        [4.1, 1. ],
#        [4. , 1. ],
#        [4.4, 1. ],
#        [4.6, 1. ],
#        [4. , 1. ],
#        [3.3, 1. ],
#        [4.2, 1. ],
#        [4.2, 1. ],
#        [4.2, 1. ],
#        [4.3, 1. ],
#        [3. , 1. ],
#        [4.1, 1. ],
#        [6. , 1. ],
#        [5.1, 1. ],
#        [5.9, 1. ],
#        [5.6, 1. ],
#        [5.8, 1. ],
#        [6.6, 1. ],
#        [4.5, 1. ],
#        [6.3, 1. ],
#        [5.8, 1. ],
#        [6.1, 1. ],
#        [5.1, 1. ],
#        [5.3, 1. ],
#        [5.5, 1. ],
#        [5. , 1. ],
#        [5.1, 1. ],
#        [5.3, 1. ],
#        [5.5, 1. ],
#        [6.7, 1. ],
#        [6.9, 1. ],
#        [5. , 1. ],
#        [5.7, 1. ],
#        [4.9, 1. ],
#        [6.7, 1. ],
#        [4.9, 1. ],
#        [5.7, 1. ],
#        [6. , 1. ],
#        [4.8, 1. ],
#        [4.9, 1. ],
#        [5.6, 1. ],
#        [5.8, 1. ],
#        [6.1, 1. ],
#        [6.4, 1. ],
#        [5.6, 1. ],
#        [5.1, 1. ],
#        [5.6, 1. ],
#        [6.1, 1. ],
#        [5.6, 1. ],
#        [5.5, 1. ],
#        [4.8, 1. ],
#        [5.4, 1. ],
#        [5.6, 1. ],
#        [5.1, 1. ],
#        [5.1, 1. ],
#        [5.9, 1. ],
#        [5.7, 1. ],
#        [5.2, 1. ],
#        [5. , 1. ],
#        [5.2, 1. ],
#        [5.4, 1. ],
#        [5.1, 1. ]])

# %%
X.shape
# Out:
# (150, 2)

# %% [markdown]
# Finalement, création d'un vecteur parametre θ, initialisé avec des coefficients aléatoires. Ce vecteur est de dimension (2, 1). Si on désire toujours reproduire le meme vecteur
# θ, on utilise comme avant np.random.seed(0)

# %%
np.random.seed(0) # pour produire toujours le meme vecteur theta aléatoire
theta=np.random.randn(2,1)
print('Theta:',theta)
# Out:
# Theta: [[1.76405235]
#  [0.40015721]]

# %% [markdown]
# ## 2. Modèle Linéaire
# On implémente un modèle selon l'équation matricielle F=X.θ et puis on teste le modèle initiale défini par la valeur initiale de θ qu'on a initialisé d'une manière aléatoire.

# %%
def model(X, theta):
    return X.dot(theta)

# %%
plt.plot(x,y,'o',label='dataset')
plt.plot(x, model(X, theta), c='r',label='modèle initial')
plt.xlabel('petal_length')
plt.ylabel('sepal_length')
plt.legend()
plt.show()

# %% [markdown]
# ## 3. Fonction coût : Erreur Quadratique Moyenne
# On mesure les erreurs du modele sur le Dataset X, y en implémenterl'erreur quadratique moyenne, Mean Squared Error (MSE) en anglais.
# ![Capture%20d'%C3%A9cran%202023-04-04%20113116.png](attachment:Capture%20d'%C3%A9cran%202023-04-04%20113116.png)
#
# Ensuite, on teste notre fonction, pour voir s'il n'y a pas de bug

# %%
def cost_function(X, y, theta):
    m = len(y)
    return 1/(2*m) * np.sum((model(X, theta) - y)**2)

# %%
cost_function(X, y, theta)
# Out:
# 3.6251772822189268

# %% [markdown]
# ![Capture%20d'%C3%A9cran%202023-04-04%20114408.png](attachment:Capture%20d'%C3%A9cran%202023-04-04%20114408.png)

# %%
def grad(X, y, theta):
    m = len(y)
    return 1/m * X.T.dot(model(X, theta) - y)

# %%
def gradient_descent(X, y, theta, learning_rate, n_iterations):
    
    cost_history = np.zeros(n_iterations) # création d'un tableau de stockage pour enregistrer l'évolution du Cout du modele
    
    for i in range(0, n_iterations):
        theta = theta - learning_rate * grad(X, y, theta) # mise a jour du parametre theta (formule du gradient descent)
        cost_history[i] = cost_function(X, y, theta) # on enregistre la valeur du Cout au tour i dans cost_history[i]
        
    return theta, cost_history

# %% [markdown]
# ## 5. Phase d'entrainement
# On définit un nombre d'itérations, ainsi qu'un pas d'apprentissage α. Une fois le modele entrainé, on observe les resultats par rapport a notre Dataset

# %%
n_iterations = 300 #0.02172855 l'erreur minimale pour 1000 itéreations
learning_rate = 0.09


theta_final, cost_history = gradient_descent(X, y, theta, learning_rate, n_iterations)

# %%
cost_history # l'historique de la fonction coût qu'on va afficher par la suite. on remarque que sa valeur déminue et c'est ça l'objectif
# Out:
# array([2.30001266, 1.75778701, 1.52157374, 1.40541913, 1.33680589,
#        1.28744062, 1.2462713 , 1.20896813, 1.17382259, 1.14014871,
#        1.10765978, 1.07622531, 1.0457763 , 1.01626827, 0.98766685,
#        0.95994211, 0.93306637, 0.90701333, 0.88175767, 0.85727495,
#        0.83354148, 0.81053434, 0.78823129, 0.76661078, 0.74565192,
#        0.72533447, 0.7056388 , 0.68654588, 0.66803725, 0.65009505,
#        0.63270194, 0.61584111, 0.59949627, 0.58365163, 0.56829189,
#        0.55340221, 0.53896819, 0.5249759 , 0.51141182, 0.49826284,
#        0.48551626, 0.47315977, 0.46118142, 0.44956964, 0.43831322,
#        0.42740129, 0.41682329, 0.40656901, 0.39662854, 0.38699228,
#        0.37765093, 0.36859544, 0.35981708, 0.35130737, 0.34305808,
#        0.33506124, 0.32730914, 0.31979427, 0.31250937, 0.30544742,
#        0.29860159, 0.29196526, 0.28553202, 0.27929566, 0.27325015,
#        0.26738965, 0.2617085 , 0.25620121, 0.25086246, 0.2456871 ,
#        0.24067011, 0.23580666, 0.23109205, 0.22652172, 0.22209126,
#        0.21779638, 0.21363294, 0.20959691, 0.2056844 , 0.20189162,
#        0.19821491, 0.19465072, 0.19119561, 0.18784623, 0.18459936,
#        0.18145185, 0.17840066, 0.17544285, 0.17257555, 0.16979601,
#        0.16710152, 0.1644895 , 0.16195741, 0.15950282, 0.15712334,
#        0.15481668, 0.15258061, 0.15041297, 0.14831167, 0.14627467,
#        0.14430001, 0.14238579, 0.14053014, 0.13873129, 0.13698748,
#        0.13529704, 0.13365833, 0.13206977, 0.13052983, 0.12903701,
#        0.12758988, 0.12618703, 0.12482712, 0.12350882, 0.12223087,
#        0.12099203, 0.1197911 , 0.11862692, 0.11749837, 0.11640436,
#        0.11534382, 0.11431574, 0.11331913, 0.11235301, 0.11141646,
#        0.11050857, 0.10962847, 0.1087753 , 0.10794824, 0.10714649,
#        0.10636927, 0.10561584, 0.10488547, 0.10417745, 0.1034911 ,
#        0.10282575, 0.10218076, 0.10155552, 0.1009494 , 0.10036184,
#        0.09979226, 0.0992401 , 0.09870485, 0.09818597, 0.09768298,
#        0.09719538, 0.0967227 , 0.09626448, 0.09582029, 0.0953897 ,
#        0.09497227, 0.09456763, 0.09417537, 0.09379511, 0.09342649,
#        0.09306915, 0.09272274, 0.09238694, 0.09206141, 0.09174585,
#        0.09143994, 0.0911434 , 0.09085593, 0.09057725, 0.09030711,
#        0.09004523, 0.08979137, 0.08954527, 0.08930671, 0.08907545,
#        0.08885126, 0.08863394, 0.08842327, 0.08821904, 0.08802106,
#        0.08782915, 0.0876431 , 0.08746275, 0.08728792, 0.08711844,
#        0.08695415, 0.08679488, 0.08664049, 0.08649082, 0.08634573,
#        0.08620509, 0.08606874, 0.08593657, 0.08580845, 0.08568424,
#        0.08556384, 0.08544712, 0.08533397, 0.08522429, 0.08511796,
#        0.08501489, 0.08491497, 0.08481811, 0.08472421, 0.08463319,
#        0.08454495, 0.08445941, 0.08437649, 0.08429611, 0.08421819,
#        0.08414265, 0.08406942, 0.08399844, 0.08392963, 0.08386292,
#        0.08379825, 0.08373557, 0.0836748 , 0.08361589, 0.08355879,
#        0.08350343, 0.08344976, 0.08339774, 0.08334731, 0.08329843,
#        0.08325104, 0.0832051 , 0.08316056, 0.08311739, 0.08307554,
#        0.08303497, 0.08299565, 0.08295752, 0.08292056, 0.08288474,
#        0.08285001, 0.08281634, 0.0827837 , 0.08275207, 0.0827214 ,
#        0.08269166, 0.08266284, 0.0826349 , 0.08260782, 0.08258156,
#        0.08255611, 0.08253144, 0.08250752, 0.08248434, 0.08246186,
#        0.08244007, 0.08241895, 0.08239847, 0.08237862, 0.08235938,
#        0.08234073, 0.08232265, 0.08230512, 0.08228813, 0.08227166,
#        0.08225569, 0.08224021, 0.0822252 , 0.08221066, 0.08219656,
#        0.08218289, 0.08216964, 0.08215679, 0.08214434, 0.08213227,
#        0.08212056, 0.08210922, 0.08209822, 0.08208756, 0.08207723,
#        0.08206721, 0.0820575 , 0.08204809, 0.08203896, 0.08203011,
#        0.08202154, 0.08201323, 0.08200517, 0.08199735, 0.08198978,
#        0.08198244, 0.08197532, 0.08196842, 0.08196174, 0.08195525,
#        0.08194897, 0.08194287, 0.08193697, 0.08193124, 0.08192569,
#        0.08192031, 0.0819151 , 0.08191004, 0.08190514, 0.08190039,
#        0.08189578, 0.08189132, 0.08188699, 0.08188279, 0.08187873])

# %%
theta_final # voici les parametres du modele une fois que la machine a été entrainée
# Out:
# array([[0.41747524],
#        [4.2676943 ]])

# %%
theta_final[0]
# Out:
# array([0.41747524])

# %%
# création d'un vecteur prédictions qui contient les prédictions de notre modele final
predictions = model(X, theta_final)

# Affichage des résultats de prédictions (en rouge) par rapport a notre Dataset (en bleu)
plt.plot(x,y,'o',label='dataset')
plt.plot(x,predictions , c='r',label='prédictions')
plt.xlabel('petal_length')
plt.ylabel('sepal_length')
plt.legend()
plt.show()

# %%
# Test: # prédire la largeur d'un pétale qui a une longueur de 2,5 cm
X_2_5= np.array([2.5,1])
pred_y_2_5=model(X_2_5, theta_final) 
print(pred_y_2_5)
# Out:
# [5.31138239]

# %% [markdown]
# ## 6. Courbe d'apprentissage
#
#    Pour vérifier si notre algorithme de Descente de gradient a bien fonctionné, on observe l'évolution de la fonction cout a travers les itérations. On est sensé obtenir une courbe qui diminue a chaque itération jusqu'a stagner a un niveau minimal (proche de zéro). Si la courbe ne suit pas ce motif, alors le pas learning_rate est peut-etre trop élevé, il faut prendre un pas plus faible.

# %%
plt.plot(range(n_iterations), cost_history)
plt.show()

# %% [markdown]
# ## 7. Evaluation du modèle - Coefficient de détermination
#
#    Le coefficient de détermination est un indice de la qualité de la prédiction de la régression linéaire. Le coefficient de détermination se situe entre 0 et 1. Plus il est proche de 1, plus la régression linéaire est en adéquation avec les données collectées

# %% [markdown]
# ![Capture%20d'%C3%A9cran%202023-04-04%20123236.png](attachment:Capture%20d'%C3%A9cran%202023-04-04%20123236.png)

# %%
def coef_determination(y, pred):
    u = ((y - pred)**2).sum()
    v = ((y - y.mean())**2).sum()
    return 1 - u/v

# %%
coef_determination(y, predictions)
# Out:
# 0.7595769915824162

# %%
dataset.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000
