# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
# %matplotlib inline

from sklearn.linear_model import LinearRegression

# %%
dataset = pd.read_csv("Advertising.csv")
dataset.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
import seaborn as sns
numeric_columns = dataset.drop(columns=['Sales'])
numeric_columns.corr()
plt.figure()
sns.heatmap(numeric_columns.corr(),annot=True)
plt.show()

# %% [markdown]
# ### TV - Radio - Newspaper

# %%
# Visualisation initiale pour comprendre les données
plt.figure(figsize=(18, 5))

# TV vs Sales
plt.subplot(1, 3, 1)
plt.scatter(dataset['TV'], dataset['Sales'])
plt.title('TV vs Sales')
plt.xlabel('TV')
plt.ylabel('Sales')

# Radio vs Sales
plt.subplot(1, 3, 2)
plt.scatter(dataset['Radio'], dataset['Sales'])
plt.title('Radio vs Sales')
plt.xlabel('Radio')

# Newspaper vs Sales
plt.subplot(1, 3, 3)
plt.scatter(dataset['Newspaper'], dataset['Sales'])
plt.title('Newspaper vs Sales')
plt.xlabel('Newspaper')

plt.show()

# %% [markdown]
# ### Diviser les données en ensemble d'apprentissage (80%) et ensemble de test (20%)

# %%
X1 = dataset[['TV']]
X2 = dataset[['Radio']]
X3 = dataset[['Newspaper']]
y = dataset[['Sales']]

X1_train, X1_test, y_train, y_test = train_test_split(X1, y, test_size=0.2, random_state=30)
X2_train, X2_test, y_train, y_test = train_test_split(X2, y, test_size=0.2, random_state=30)
X3_train, X3_test, y_train, y_test = train_test_split(X3, y, test_size=0.2, random_state=30)
print(X1.shape )
print(X1_train.shape)
print(X1_test.shape)
# Out:
# (200, 1)
# (160, 1)
# (40, 1)

# %% [markdown]
# ### Splitting the data into training and testing data

# %%
regr1 = LinearRegression()
regr2 = LinearRegression()
regr3 = LinearRegression()
 
regr1.fit(X1_train, y_train)
regr2.fit(X2_train, y_train)
regr3.fit(X3_train, y_train)

print("Accuracy of TV : ", regr1.score(X1_test, y_test)*100, "%")
print("Accuracy of Radio : ", regr2.score(X2_test, y_test)*100, "%")
print("Accuracy of Newspaper : ", regr3.score(X3_test, y_test)*100, "%")
# Out:
# Accuracy of TV :  81.47054411104466 %
# Accuracy of Radio :  7.316144982048078 %
# Accuracy of Newspaper :  0.7841555118711097 %
