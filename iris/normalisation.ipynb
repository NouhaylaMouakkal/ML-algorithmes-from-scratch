# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dataset=pd.read_csv("Advertising.csv")

# %%
dataset.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
dataset.corr()
# Out:
#                  TV     Radio  Newspaper     Sales
# TV         1.000000  0.054809   0.056648  0.901208
# Radio      0.054809  1.000000   0.354104  0.349631
# Newspaper  0.056648  0.354104   1.000000  0.157960
# Sales      0.901208  0.349631   0.157960  1.000000

# %%
df=dataset[['TV','Newspaper','Radio']]
columns = ['TV','Newspaper','Radio']
df
# Out:
#         TV  Newspaper  Radio
# 0    230.1       69.2   37.8
# 1     44.5       45.1   39.3
# 2     17.2       69.3   45.9
# 3    151.5       58.5   41.3
# 4    180.8       58.4   10.8
# ..     ...        ...    ...
# 195   38.2       13.8    3.7
# 196   94.2        8.1    4.9
# 197  177.0        6.4    9.3
# 198  283.6       66.2   42.0
# 199  232.1        8.7    8.6
#
# [200 rows x 3 columns]

# %%
x = dataset[columns].values.reshape(-1, 3)  
y = dataset['Sales'].values.reshape(-1, 1) 
print(x.shape)
print(y.shape)
print(x)
# Out:
# (200, 3)
# (200, 1)
# [[230.1  69.2  37.8]
#  [ 44.5  45.1  39.3]
#  [ 17.2  69.3  45.9]
#  [151.5  58.5  41.3]
#  [180.8  58.4  10.8]
#  [  8.7  75.   48.9]
#  [ 57.5  23.5  32.8]
#  [120.2  11.6  19.6]
#  [  8.6   1.    2.1]
#  [199.8  21.2   2.6]
#  [ 66.1  24.2   5.8]
#  [214.7   4.   24. ]
#  [ 23.8  65.9  35.1]
#  [ 97.5   7.2   7.6]
#  [204.1  46.   32.9]
#  [195.4  52.9  47.7]
#  [ 67.8 114.   36.6]
#  [281.4  55.8  39.6]
#  [ 69.2  18.3  20.5]
#  [147.3  19.1  23.9]
#  [218.4  53.4  27.7]
#  [237.4  23.5   5.1]
#  [ 13.2  49.6  15.9]
#  [228.3  26.2  16.9]
#  [ 62.3  18.3  12.6]
#  [262.9  19.5   3.5]
#  [142.9  12.6  29.3]
#  [240.1  22.9  16.7]
#  [248.8  22.9  27.1]
#  [ 70.6  40.8  16. ]
#  [292.9  43.2  28.3]
#  [112.9  38.6  17.4]
#  [ 97.2  30.    1.5]
#  [265.6   0.3  20. ]
#  [ 95.7   7.4   1.4]
#  [290.7   8.5   4.1]
#  [266.9   5.   43.8]
#  [ 74.7  45.7  49.4]
#  [ 43.1  35.1  26.7]
#  [228.   32.   37.7]
#  [202.5  31.6  22.3]
#  [177.   38.7  33.4]
# ...

# %%
X = dataset[columns].values.reshape(-1, 3)  
Y = dataset['Sales'].values.reshape(-1, 1) 
print(X)
# Out:
# [[230.1  69.2  37.8]
#  [ 44.5  45.1  39.3]
#  [ 17.2  69.3  45.9]
#  [151.5  58.5  41.3]
#  [180.8  58.4  10.8]
#  [  8.7  75.   48.9]
#  [ 57.5  23.5  32.8]
#  [120.2  11.6  19.6]
#  [  8.6   1.    2.1]
#  [199.8  21.2   2.6]
#  [ 66.1  24.2   5.8]
#  [214.7   4.   24. ]
#  [ 23.8  65.9  35.1]
#  [ 97.5   7.2   7.6]
#  [204.1  46.   32.9]
#  [195.4  52.9  47.7]
#  [ 67.8 114.   36.6]
#  [281.4  55.8  39.6]
#  [ 69.2  18.3  20.5]
#  [147.3  19.1  23.9]
#  [218.4  53.4  27.7]
#  [237.4  23.5   5.1]
#  [ 13.2  49.6  15.9]
#  [228.3  26.2  16.9]
#  [ 62.3  18.3  12.6]
#  [262.9  19.5   3.5]
#  [142.9  12.6  29.3]
#  [240.1  22.9  16.7]
#  [248.8  22.9  27.1]
#  [ 70.6  40.8  16. ]
#  [292.9  43.2  28.3]
#  [112.9  38.6  17.4]
#  [ 97.2  30.    1.5]
#  [265.6   0.3  20. ]
#  [ 95.7   7.4   1.4]
#  [290.7   8.5   4.1]
#  [266.9   5.   43.8]
#  [ 74.7  45.7  49.4]
#  [ 43.1  35.1  26.7]
#  [228.   32.   37.7]
#  [202.5  31.6  22.3]
#  [177.   38.7  33.4]
#  [293.6   1.8  27.7]
# ...

# %%
product_column1 = np.multiply(X[:, 0], X[:, 1])
product_column2 = np.multiply(X[:, 0], X[:, 2])
product_column3 = np.multiply(X[:, 1], X[:, 2])
product_column4 = np.multiply(X[:, 0], X[:, 0])
product_column5 = np.multiply(X[:, 1], X[:, 1])
product_column6 = np.multiply(X[:, 2], X[:, 2])


X = np.column_stack((product_column1, X))
X = np.column_stack((product_column2, X))
X = np.column_stack((product_column3, X))
X = np.column_stack((product_column4, X))
X = np.column_stack((product_column5, X))
X = np.column_stack((product_column6, X))

print(X.shape)
print(X)
# Out:
# (200, 9)
# [[1.428840e+03 4.788640e+03 5.294601e+04 ... 2.301000e+02 6.920000e+01
#   3.780000e+01]
#  [1.544490e+03 2.034010e+03 1.980250e+03 ... 4.450000e+01 4.510000e+01
#   3.930000e+01]
#  [2.106810e+03 4.802490e+03 2.958400e+02 ... 1.720000e+01 6.930000e+01
#   4.590000e+01]
#  ...
#  [8.649000e+01 4.096000e+01 3.132900e+04 ... 1.770000e+02 6.400000e+00
#   9.300000e+00]
#  [1.764000e+03 4.382440e+03 8.042896e+04 ... 2.836000e+02 6.620000e+01
#   4.200000e+01]
#  [7.396000e+01 7.569000e+01 5.387041e+04 ... 2.321000e+02 8.700000e+00
#   8.600000e+00]]

# %%
from sklearn.model_selection import train_test_split


X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)
print(X_train)
# Out:
# [[5.929000e+01 5.336100e+02 1.345600e+04 ... 1.160000e+02 2.310000e+01
#   7.700000e+00]
#  [8.649000e+01 4.096000e+01 3.132900e+04 ... 1.770000e+02 6.400000e+00
#   9.300000e+00]
#  [7.128900e+02 1.232010e+03 1.857610e+03 ... 4.310000e+01 3.510000e+01
#   2.670000e+01]
#  ...
#  [1.122250e+03 3.481000e+03 4.739329e+04 ... 2.177000e+02 5.900000e+01
#   3.350000e+01]
#  [1.000000e+02 3.097600e+02 2.742336e+04 ... 1.656000e+02 1.760000e+01
#   1.000000e+01]
#  [1.020100e+02 4.579600e+02 7.851204e+04 ... 2.802000e+02 2.140000e+01
#   1.010000e+01]]

# %%
X_train.shape
print(X[:10])
# Out:
# [[1.428840e+03 4.788640e+03 5.294601e+04 2.615760e+03 8.697780e+03
#   1.592292e+04 2.301000e+02 6.920000e+01 3.780000e+01]
#  [1.544490e+03 2.034010e+03 1.980250e+03 1.772430e+03 1.748850e+03
#   2.006950e+03 4.450000e+01 4.510000e+01 3.930000e+01]
#  [2.106810e+03 4.802490e+03 2.958400e+02 3.180870e+03 7.894800e+02
#   1.191960e+03 1.720000e+01 6.930000e+01 4.590000e+01]
#  [1.705690e+03 3.422250e+03 2.295225e+04 2.416050e+03 6.256950e+03
#   8.862750e+03 1.515000e+02 5.850000e+01 4.130000e+01]
#  [1.166400e+02 3.410560e+03 3.268864e+04 6.307200e+02 1.952640e+03
#   1.055872e+04 1.808000e+02 5.840000e+01 1.080000e+01]
#  [2.391210e+03 5.625000e+03 7.569000e+01 3.667500e+03 4.254300e+02
#   6.525000e+02 8.700000e+00 7.500000e+01 4.890000e+01]
#  [1.075840e+03 5.522500e+02 3.306250e+03 7.708000e+02 1.886000e+03
#   1.351250e+03 5.750000e+01 2.350000e+01 3.280000e+01]
#  [3.841600e+02 1.345600e+02 1.444804e+04 2.273600e+02 2.355920e+03
# ...

# %%
#Scaler
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_train)
means = scaler.mean_
scales = np.sqrt(scaler.var_)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = (X_test - means)/scales
print(X_test_scaled)
# Out:
# [[ 3.53971232e-01  9.42058287e-01 -1.14868405e-01  9.76876694e-01
#    5.01838751e-01  8.80626951e-01  1.57812165e-01  1.13227461e+00
#    5.91127268e-01]
#  [ 2.10942255e+00  9.42058287e-01  3.37942156e-01  1.93264278e+00
#    1.75835198e+00  1.24415002e+00  5.39252835e-01  1.13227461e+00
#    1.68199613e+00]
#  [ 8.21831001e-02  3.52960294e-01  2.21022509e+00  4.72919345e-01
#    1.44681051e+00  1.74008652e+00  1.69783431e+00  6.53800957e-01
#    3.67533029e-01]
#  [ 8.53150073e-01  4.64691550e-01 -1.15818806e+00  9.72657224e-01
#   -9.26299991e-01 -8.55484765e-01 -1.64363349e+00  7.52455319e-01
#    9.50233166e-01]
#  [ 2.28226864e+00 -8.19965110e-01  7.45003170e-01 -7.23075988e-01
#    2.20357258e+00 -8.17781414e-01  8.35136719e-01 -1.31928629e+00
#    1.77007871e+00]
#  [ 6.65316933e-01  9.28711204e-01 -9.41772181e-01  1.17086010e+00
#   -2.62821262e-01 -1.21427584e-01 -8.90258461e-01  1.12240918e+00
#    8.21497089e-01]
# ...

# %%
ones_column = np.ones((X_train_scaled.shape[0], 1))
ones_column2 = np.ones((X_test_scaled.shape[0], 1))
X_train_scaled = np.hstack((X_train_scaled, ones_column))
X_test_scaled = np.hstack((X_test_scaled, ones_column2))
print(X_test_scaled)
# Out:
# [[ 3.53971232e-01  9.42058287e-01 -1.14868405e-01  9.76876694e-01
#    5.01838751e-01  8.80626951e-01  1.57812165e-01  1.13227461e+00
#    5.91127268e-01  1.00000000e+00]
#  [ 2.10942255e+00  9.42058287e-01  3.37942156e-01  1.93264278e+00
#    1.75835198e+00  1.24415002e+00  5.39252835e-01  1.13227461e+00
#    1.68199613e+00  1.00000000e+00]
#  [ 8.21831001e-02  3.52960294e-01  2.21022509e+00  4.72919345e-01
#    1.44681051e+00  1.74008652e+00  1.69783431e+00  6.53800957e-01
#    3.67533029e-01  1.00000000e+00]
#  [ 8.53150073e-01  4.64691550e-01 -1.15818806e+00  9.72657224e-01
#   -9.26299991e-01 -8.55484765e-01 -1.64363349e+00  7.52455319e-01
#    9.50233166e-01  1.00000000e+00]
#  [ 2.28226864e+00 -8.19965110e-01  7.45003170e-01 -7.23075988e-01
#    2.20357258e+00 -8.17781414e-01  8.35136719e-01 -1.31928629e+00
#    1.77007871e+00  1.00000000e+00]
#  [ 6.65316933e-01  9.28711204e-01 -9.41772181e-01  1.17086010e+00
# ...

# %%
np.random.seed(0) # pour produire toujours le meme vecteur theta aléatoire
theta=np.random.randn(10,1)
print('Theta:',theta)
# Out:
# Theta: [[ 1.76405235]
#  [ 0.40015721]
#  [ 0.97873798]
#  [ 2.2408932 ]
#  [ 1.86755799]
#  [-0.97727788]
#  [ 0.95008842]
#  [-0.15135721]
#  [-0.10321885]
#  [ 0.4105985 ]]

# %%
def model(X, theta):
    return X.dot(theta)

# %%
def cost_function(X, y, theta):
    m = len(y)
    return 1/(2*m) * np.sum((model(X, theta) - y)**2)

# %%
cost_function(X_train_scaled, y_train, theta)
# Out:
# 119.46407226382286

# %%
def grad(X, y, theta):
    m = len(y)
    return 1/m * X.T.dot(model(X, theta) - y)

# %%
def gradient_descent(X, y, theta, learning_rate, n_iterations):
    
    cost_history = np.zeros(n_iterations) # création d'un tableau de stockage pour enregistrer l'évolution du Cout du modele
    
    for i in range(0, n_iterations):
        theta = theta - learning_rate * grad(X, y, theta) # mise a jour du parametre theta (formule du gradient descent)
        cost_history[i] = cost_function(X, y, theta) # on enregistre la valeur du Cout au tour i dans cost_history[i]
        
    return theta, cost_history

# %%
n_iterations = 4000
learning_rate = 0.4

theta_final, cost_history = gradient_descent(X_train_scaled, y_train, theta, learning_rate, n_iterations)

# %%
theta_final
# Out:
# array([[ 1.05327008],
#        [ 0.13492603],
#        [-2.69053014],
#        [ 0.14675777],
#        [ 1.38577988],
#        [-0.11930976],
#        [ 6.41397115],
#        [-0.03892875],
#        [-0.47204546],
#        [15.330625  ]])

# %%
predictions = model(X_train_scaled, theta_final)
predictions
# Out:
# array([[12.74372903],
#        [15.81524355],
#        [ 9.05276406],
#        [ 9.64629566],
#        [16.9787182 ],
#        [ 7.85334036],
#        [10.4337584 ],
#        [15.61591055],
#        [12.0550487 ],
#        [11.47651837],
#        [13.90310124],
#        [15.2808866 ],
#        [ 8.8059827 ],
#        [ 7.24849398],
#        [10.32053534],
#        [13.36449002],
#        [10.57359815],
#        [24.82111799],
#        [ 6.75100405],
#        [16.24049508],
#        [19.30811007],
#        [17.18937141],
#        [13.16348875],
#        [ 8.50081683],
#        [18.6901476 ],
#        [ 6.6259288 ],
#        [22.02800451],
#        [ 6.49613208],
#        [13.59701531],
#        [ 8.44913024],
#        [11.95699823],
#        [10.55365105],
#        [17.03714923],
#        [18.43934043],
#        [16.402355  ],
#        [18.20863304],
#        [15.94434936],
#        [20.41149101],
#        [17.02577451],
#        [22.11454526],
#        [ 9.11387002],
# ...

# %%
plt.plot(range(n_iterations), cost_history)
plt.show()

# %%
def coef_determination(y, pred):
    u = ((y - pred)**2).sum()
    v = ((y - y.mean())**2).sum()
    return 1 - u/v

# %%
print(coef_determination(y_train, predictions))
predictions = model(X_test_scaled, theta_final)
print(coef_determination(y_test, predictions))
# Out:
# 0.9288133512730626
# 0.9533174341074796

# %%
'''
pour la reggression multiple simple on a : 
Coeff de determination pour train :  0.9001415981528272
Coeff de determination pour test :  0.9059033682359278
donc on peut remarque une augmentation du precision

'''
